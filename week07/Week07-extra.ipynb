# %%
import pandas as pd

# Load the Excel file
file_path = '/Users/sohrabtellaie/Documents/GitHub/PrinciplesOfDataScienceCity/week07/london-borough-profilesV2.xlsx'
londonBorough = pd.read_excel(file_path)

# Force all columns to numeric, replacing non-numeric values with NaN
londonBorough_feat = londonBorough.apply(pd.to_numeric, errors='coerce')

# Drop columns where all values are NaN
londonBorough_feat = londonBorough_feat.dropna(axis=1, how='all')

# Display the cleaned data
londonBorough_feat.head()
# Out:
#    GLA Population Estimate 2013  GLA Household Estimate 2013  \
# 0                          8000                  4514.371383
# 1                        195600                 73261.408580
# 2                        370000                141385.794900
# 3                        236500                 94701.226400
# 4                        320200                114318.553900
#
#    Inland Area (Hectares)  Population density (per hectare) 2013  \
# 0                   290.4                              27.525868
# 1                  3610.8                              54.160527
# 2                  8674.8                              42.651374
# 3                  6058.1                              39.044243
# 4                  4323.3                              74.063670
#
#    Average Age, 2013  Proportion of population aged 0-15, 2013  \
# 0          41.303887                                  7.948036
# 1          33.228935                                 26.072939
# ...
